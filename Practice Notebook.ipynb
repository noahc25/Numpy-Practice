# %% [markdown]
# # Practice Notebook: Numpy. After completeion submit it via moodle  (100 points)

# %% [markdown]
# ## 1. Import numpy, Image, PrettyTable, random libraries

# %%
import numpy as np

# %%
from PIL import Image

# %%
from prettytable import PrettyTable

# %%
from numpy import random

# %% [markdown]
# ## 2. Open any two images from the image list using Image library and save it to image1, and image2

# %%
image1=Image.open("Pic1.jfif")
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=444x355 at 0x7FEBD813A8E0>

# %%
image2=Image.open("Pic2.jfif")
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=442x355 at 0x7FEBF9C21850>

# %% [markdown]
# ## 3. Color image is a 3d Numpy array. Find out the shape of each of those images and save it array1, and array2

# %%
array1=np.array(image1)
np.shape(array1)
# Out:
# (355, 444, 3)

# %%
array2=np.array(image2)
np.shape(array2)
# Out:
# (355, 442, 3)

# %% [markdown]
# ## 4. If two of the image is different size, resize them. You can either resize both of them in a particular size like 400x400 or resize either of them
#
# ### use resize library from PIL
# Sample: resizedimage=image1.resize((400,400), resample=Image.NEAREST)

# %%
resizedimage2=image2.resize((444,355), resample=Image.NEAREST)

# %%
np.shape(resizedimage2)
# Out:
# (355, 444, 3)

# %% [markdown]
# ## Find out the shape of each of those `resizedimage` and save it array1, and array2

# %%
array1=np.array(image1)
np.shape(array1)
# Out:
# (355, 444, 3)

# %%
array2=np.array(resizedimage2)
np.shape(array2)
# Out:
# (355, 444, 3)

# %% [markdown]
# ## 5.  Write down a function called "inspect" to inspect array1 and array2 Shape, length, Dimensions, and Datatype using Preetytable. Your pretty table should contain a title and look like similar to the following:
# ![image-2.png](attachment:image-2.png)

# %%
def inspect(array):
    PT=PrettyTable()
    PT.field_names=["Shape", "Length", "Dimensions", "Datatype"]
    PT.add_row([array.shape, len(array), array.ndim, array.dtype])
    PT.title="Numpy Array Inspection"
    print(PT)

# %%
inspect(array1)
# Out:
# +------------------------------------------------+
# |             Numpy Array Inspection             |
# +---------------+--------+------------+----------+
# |     Shape     | Length | Dimensions | Datatype |
# +---------------+--------+------------+----------+
# | (355, 444, 3) |  355   |     3      |  uint8   |
# +---------------+--------+------------+----------+

# %%
inspect(array2)
# Out:
# +------------------------------------------------+
# |             Numpy Array Inspection             |
# +---------------+--------+------------+----------+
# |     Shape     | Length | Dimensions | Datatype |
# +---------------+--------+------------+----------+
# | (355, 444, 3) |  355   |     3      |  uint8   |
# +---------------+--------+------------+----------+

# %% [markdown]
# ## 6. Perform Element wise and Array Wise comparison of array1 and array2 and add necessary comments

# %%
array1==array2
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
array1>array2
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]])

# %%
array2>array1
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
np.array_equal(array1, array2)
# Out:
# False

# %% [markdown]
# ## 7. Create a 3D random array of saze of your array1 and array2, give it name array3

# %%
array3=random.random((array1.shape))
print(array3)
# Out:
# [[[0.60525848 0.91248413 0.13363643]
#   [0.2477682  0.13674384 0.17954516]
#   [0.27836538 0.25050163 0.63360841]
#   ...
#   [0.54705085 0.18229303 0.77108117]
#   [0.18589329 0.19737193 0.96207854]
#   [0.0216291  0.88317084 0.3311425 ]]
#
#  [[0.79519211 0.93938063 0.19690147]
#   [0.25665237 0.41062311 0.06039976]
#   [0.85403502 0.833192   0.24036088]
#   ...
#   [0.90037741 0.01533599 0.00512861]
#   [0.27291022 0.65685851 0.40182085]
#   [0.70030304 0.87567677 0.06654716]]
#
#  [[0.96820663 0.2159451  0.05405071]
#   [0.44216839 0.44114141 0.69702789]
#   [0.07889405 0.18990836 0.2484212 ]
#   ...
#   [0.97615543 0.30371584 0.0692589 ]
#   [0.80411622 0.19785976 0.12404442]
#   [0.51124023 0.35995798 0.78609768]]
#
#  ...
#
#  [[0.34102805 0.80178208 0.52427039]
#   [0.40105868 0.68929084 0.74970783]
#   [0.8275257  0.98064426 0.30325451]
#   ...
#   [0.9767351  0.14311331 0.07034901]
#   [0.18144205 0.63094706 0.52019204]
#   [0.92115888 0.55417938 0.78215376]]
#
#  [[0.71774034 0.4639899  0.36801906]
#   [0.37116183 0.73686422 0.38945973]
#   [0.65331608 0.59886535 0.35722097]
#   ...
#   [0.83837099 0.57589549 0.62954038]
#   [0.56357258 0.91016553 0.12975968]
#   [0.49596788 0.61375969 0.75190599]]
#
#  [[0.19131817 0.49832479 0.66271378]
#   [0.40740067 0.61808502 0.50656103]
#   [0.41311267 0.64001972 0.16550274]
#   ...
#   [0.95586054 0.82675008 0.05322469]
#   [0.82505701 0.77869063 0.55650675]
#   [0.14135612 0.31864163 0.16327995]]]

# %% [markdown]
# ## 8.Create a function called "calculation" to display `sum, min, max, mean, standard deviation, median calculations about a NumPy array using PrettyTable. Test it for array1,2,3
# ![image.png](attachment:image.png)

# %%
def calculation(array):
    PT=PrettyTable()
    PT.field_names=["Sum", "Min", "Max", "Mean", "Standard Deviation", "Median"]
    PT.add_row([array.sum(), array.min(), array.max(), array.mean(), np.std(array), np.median(array)])
    PT.title="Numpy Array Calculations"
    print(PT)

# %%
calculation(array1)
# Out:
# +-----------------------------------------------------------------------+
# |                        Numpy Array Calculations                       |
# +----------+-----+-----+------------------+--------------------+--------+
# |   Sum    | Min | Max |       Mean       | Standard Deviation | Median |
# +----------+-----+-----+------------------+--------------------+--------+
# | 35717204 |  0  | 255 | 75.5344161062471 | 70.82475432514661  |  60.0  |
# +----------+-----+-----+------------------+--------------------+--------+

# %%
calculation(array2)
# Out:
# +------------------------------------------------------------------------+
# |                        Numpy Array Calculations                        |
# +----------+-----+-----+-------------------+--------------------+--------+
# |   Sum    | Min | Max |        Mean       | Standard Deviation | Median |
# +----------+-----+-----+-------------------+--------------------+--------+
# | 39620710 |  0  | 255 | 83.78951486697966 |  69.9930467119953  |  61.0  |
# +----------+-----+-----+-------------------+--------------------+--------+

# %%
calculation(array3)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------+
# |                                                   Numpy Array Calculations                                                   |
# +--------------------+----------------------+--------------------+-------------------+--------------------+--------------------+
# |        Sum         |         Min          |        Max         |        Mean       | Standard Deviation |       Median       |
# +--------------------+----------------------+--------------------+-------------------+--------------------+--------------------+
# | 236624.38572807953 | 1.44370262811222e-06 | 0.9999996417215843 | 0.500411085158566 | 0.2886505210459022 | 0.5009717018596673 |
# +--------------------+----------------------+--------------------+-------------------+--------------------+--------------------+

# %% [markdown]
# ## 9.Create a function called "arithmatic" to display `Subtraction (np.subtract(a,b)), Addition,  Multiplication calculations about two NumPy array using PrettyTable. Test it for
# * array1, array3
# * array2, array3
# * array1, array2
# ![image.png](attachment:image.png)

# %%
array1.shape
# Out:
# (355, 444, 3)

# %%
array3.shape
# Out:
# (355, 444, 3)

# %%
def arithmetic(arraya, arrayb):
    PT=PrettyTable()
    PT.title="Numpy Array Arithmetic Operation"
    PT.field_names=["Subtraction", "Addition", "Multiplication"]
    PT.add_row([np.subtract(arraya, arrayb), np.add(arraya, arrayb), np.multiply(arraya, arrayb)])
    print(PT)

# %%
arithmetic(array1,array3)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                 Numpy Array Arithmetic Operation                                                                |
# +-------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |                      Subtraction                      |                      Addition                      |                   Multiplication                   |
# +-------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  [[[ 4.93947415e+01  7.10875159e+01  9.48663636e+01]  |  [[[5.06052585e+01 7.29124841e+01 9.51336364e+01]  |  [[[3.02629239e+01 6.56988574e+01 1.26954605e+01]  |
# |    [ 5.67522318e+01  7.88632562e+01  1.01820455e+02]  |    [5.72477682e+01 7.91367438e+01 1.02179545e+02]  |    [1.41227873e+01 1.08027637e+01 1.83136059e+01]  |
# |    [ 3.67216346e+01  5.87494984e+01  8.13663916e+01]  |    [3.72783654e+01 5.92505016e+01 8.26336084e+01]  |    [1.02995190e+01 1.47795962e+01 5.19558899e+01]  |
# |                           ...                         |                         ...                        |                         ...                        |
# |    [ 2.45294915e+00  1.81770697e+00 -7.71081172e-01]  |    [3.54705085e+00 2.18229303e+00 7.71081172e-01]  |    [1.64115256e+00 3.64586064e-01 0.00000000e+00]  |
# |    [ 2.81410671e+00  1.80262807e+00 -9.62078536e-01]  |    [3.18589329e+00 2.19737193e+00 9.62078536e-01]  |    [5.57679878e-01 3.94743862e-01 0.00000000e+00]  |
# |    [ 2.97837090e+00  1.11682916e+00 -3.31142500e-01]] |   [3.02162910e+00 2.88317084e+00 3.31142500e-01]]  |   [6.48872976e-02 1.76634168e+00 0.00000000e+00]]  |
# |                                                       |                                                    |                                                    |
# |   [[ 4.22048079e+01  6.70606194e+01  8.98030985e+01]  |   [[4.37951921e+01 6.89393806e+01 9.01969015e+01]  |   [[3.41932605e+01 6.38778830e+01 1.77211319e+01]  |
# |    [ 4.57433476e+01  7.05893769e+01  9.29396002e+01]  |    [4.62566524e+01 7.14106231e+01 9.30603998e+01]  |    [1.18060088e+01 2.91542407e+01 5.61717754e+00]  |
# |    [ 3.81459650e+01  6.31668080e+01  8.57596391e+01]  |    [3.98540350e+01 6.48331920e+01 8.62403609e+01]  |    [3.33073659e+01 5.33242881e+01 2.06710354e+01]  |
# |                           ...                         |                         ...                        |                         ...                        |
# |    [ 9.96225873e-02  9.84664009e-01  9.94871390e-01]  |    [1.90037741e+00 1.01533599e+00 1.00512861e+00]  |    [9.00377413e-01 1.53359912e-02 5.12861002e-03]  |
# |    [ 7.27089775e-01  3.43141488e-01  5.98179146e-01]  |    [1.27291022e+00 1.65685851e+00 1.40182085e+00]  |    [2.72910225e-01 6.56858512e-01 4.01820854e-01]  |
# |    [ 2.99696960e-01  1.24323229e-01  9.33452841e-01]] |   [1.70030304e+00 1.87567677e+00 1.06654716e+00]]  |   [7.00303040e-01 8.75676771e-01 6.65471589e-02]]  |
# |                                                       |                                                    |                                                    |
  |
# |                           ...                         |                      ...                     |                         ...                        |
# |    [ 1.26161629e+02  1.78424105e+02  2.15370460e+02]  |    [127.83837099 179.57589549 216.62954038]  |    [1.06473116e+02 1.03085293e+02 1.35980722e+02]  |
# |    [ 1.27436427e+02  1.79089834e+02  2.18870240e+02]  |    [128.56357258 180.91016553 219.12975968]  |    [7.21372899e+01 1.63829795e+02 2.84173699e+01]  |
# |    [ 1.23504032e+02  1.77386240e+02  2.15248094e+02]] |   [124.49596788 178.61375969 216.75190599]]  |   [6.15000165e+01 1.09249225e+02 1.62411693e+02]]  |
# |                                                       |                                              |                                                    |
# |   [[ 4.68086818e+01  9.85016752e+01  1.45337286e+02]  |   [[ 47.19131817  99.49832479 146.66271378]  |   [[8.99195413e+00 4.93341544e+01 9.67562112e+01]  |
# |    [ 4.55925993e+01  9.73819150e+01  1.44493439e+02]  |    [ 46.40740067  98.61808502 145.50656103]  |    [1.87404306e+01 6.05723317e+01 7.34513493e+01]  |
# |    [ 4.45868873e+01  9.63599803e+01  1.43834497e+02]  |    [ 45.41311267  97.64001972 144.16550274]  |    [1.85900699e+01 6.20819131e+01 2.38323950e+01]  |
# |                           ...                         |                      ...                     |                         ...                        |
# |    [ 1.28044139e+02  1.80173250e+02  2.17946775e+02]  |    [129.95586054 181.82675008 218.05322469]  |    [1.23306009e+02 1.49641764e+02 1.16029828e+01]  |
# |    [ 1.25174943e+02  1.77221309e+02  2.16443493e+02]  |    [126.82505701 178.77869063 217.55650675]  |    [1.03957183e+02 1.38606932e+02 1.20761965e+02]  |
# |   [ 1.20858644e+02  1.74681358e+02  2.12836720e+02]]] |   [121.14135612 175.31864163 213.16327995]]] |   [1.71040907e+01 5.57622847e+01 3.47786298e+01]]] |
# +-------------------------------------------------------+----------------------------------------------+----------------------------------------------------+

# %%
arithmetic(array1, array2)
# Out:
# +-----------------------------------------------------------+
# |              Numpy Array Arithmetic Operation             |
# +-------------------+-------------------+-------------------+
# |    Subtraction    |      Addition     |   Multiplication  |
# +-------------------+-------------------+-------------------+
# |  [[[ 50  59  57]  |  [[[ 50  85 133]  |  [[[  0 168  26]  |
# |    [ 57  65  63]  |    [ 57  93 141]  |    [  0  82 138]  |
# |    [ 37  44  42]  |    [ 37  74 122]  |    [  0 117 208]  |
# |         ...       |         ...       |         ...       |
# |    [243 224 202]  |    [ 19  36  54]  |    [ 48  68   0]  |
# |    [241 222 198]  |    [ 21  38  58]  |    [ 54  72   0]  |
# |    [241 222 196]] |    [ 21  38  60]] |    [ 54  72   0]] |
# |                   |                   |                   |
# |   [[ 43  53  50]  |   [[ 43  83 130]  |   [[  0 252  16]  |
# |    [ 46  56  53]  |    [ 46  86 133]  |    [  0  41 136]  |
# |    [ 39  48  45]  |    [ 39  80 127]  |    [  0   0 198]  |
# |         ...       |         ...       |         ...       |
# |    [241 223 201]  |    [ 17  35  57]  |    [ 16  34  56]  |
# |    [239 221 199]  |    [ 19  37  59]  |    [ 18  36  58]  |
# |    [239 221 197]] |    [ 19  37  61]] |    [ 18  36  60]] |
# |                   |                   |                   |
# |   [[ 40  49  46]  |   [[ 42  83 130]  |   [[ 41  98 112]  |
# |    [ 32  41  38]  |    [ 34  75 122]  |    [ 33 218  32]  |
# |    [ 39  48  45]  |    [ 41  82 129]  |    [ 40  81  70]  |
# |         ...       |         ...       |         ...       |
# |    [240 222 200]  |    [ 16  34  56]  |    [  0   0   0]  |
# |    [238 220 198]  |    [ 18  36  58]  |    [  0   0   0]  |
# |    [238 220 196]] |    [ 18  36  60]] |    [  0   0   0]] |
# |                   |                   |                   |
# |         ...       |         ...       |         ...       |
# |                   |                   |                   |
# |   [[212 160 113]  |   [[ 44  96 143]  |   [[  0   0   0]  |
# |    [209 157 110]  |    [ 47  99 146]  |    [  0   0   0]  |
# |    [207 155 108]  |    [ 49 101 148]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [132  80  43]  |    [124 176 213]  |    [  0   0   0]  |
# |    [123  71  32]  |    [133 185 224]  |    [  0   0   0]  |
# |    [138  84  46]] |    [140 194 232]] |    [139 221 127]] |
# |                   |                   |                   |
# |   [[211 159 112]  |   [[ 45  97 144]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [209 157 110]  |    [ 47  99 146]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [130  78  41]  |    [128 180 217]  |    [127 179 216]  |
# |    [135  83  44]  |    [135 187 226]  |    [128 236 253]  |
# |    [180 126  88]] |    [172 226   8]] |    [ 64  96 128]] |
# |                   |                   |                   |
# |   [[209 157 110]  |   [[ 47  99 146]  |   [[  0   0   0]  |
# |    [210 158 111]  |    [ 46  98 145]  |    [  0   0   0]  |
# |    [211 159 112]  |    [ 45  97 144]  |    [  0   0   0]  |
# |         ...       |         ...       |         ...       |
# |    [127  75  38]  |    [129 181 218]  |    [  0   0   0]  |
# |    [136  84  45]  |    [132 184 223]  |    [244  44  22]  |
# |   [197 143 105]]] |   [183 237  19]]] |   [ 78  98 150]]] |
# +-------------------+-------------------+-------------------+

# %%
arraya+arrayb, arraya*arrayb])
, "Addition", "Multiplication"]

# %%
array1.shape
# Out:
# (355, 444, 3)

# %%
array2.shape
# Out:
# (355, 444, 3)

# %% [markdown]
# ## 10. What is the difference between reshape and resize? Reshape and resize 3D array2 to a 2D array. Make sure keep in mind the original shape.

# %%
#Reshape changes the dimensions, resize will change the original image

# %%
np.shape(array2)
# Out:
# (355, 444, 3)

# %%
array2.size
# Out:
# 472860

# %%
array2.reshape(236430,2)
# Out:
# array([[  0,  13],
#        [ 38,   0],
#        [ 14,  39],
#        ...,
#        [126, 178],
#        [217, 121],
#        [175, 213]], dtype=uint8)

# %% [markdown]
# ## 11. Vertically stack array1 and array3 and create new array4

# %%
array4=np.vstack((array1, array3))
array4
# Out:
# array([[[5.00000000e+01, 7.20000000e+01, 9.50000000e+01],
#         [5.70000000e+01, 7.90000000e+01, 1.02000000e+02],
#         [3.70000000e+01, 5.90000000e+01, 8.20000000e+01],
#         ...,
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00]],
#
#        [[4.30000000e+01, 6.80000000e+01, 9.00000000e+01],
#         [4.60000000e+01, 7.10000000e+01, 9.30000000e+01],
#         [3.90000000e+01, 6.40000000e+01, 8.60000000e+01],
#         ...,
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00]],
#
#        [[4.10000000e+01, 6.60000000e+01, 8.80000000e+01],
#         [3.30000000e+01, 5.80000000e+01, 8.00000000e+01],
#         [4.00000000e+01, 6.50000000e+01, 8.70000000e+01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[3.29891444e-01, 9.43673815e-01, 3.50068070e-01],
#         [1.92637855e-01, 2.95057392e-01, 9.25443149e-01],
#         [7.61222656e-01, 2.39532629e-01, 8.73680575e-01],
#         ...,
#         [7.27397907e-01, 3.73350888e-01, 5.80109743e-01],
#         [6.41273533e-01, 4.64048017e-01, 1.52815829e-01],
#         [9.40563043e-01, 6.73622595e-01, 5.14337089e-01]],
#
#        [[5.98202782e-01, 7.32695938e-01, 4.23676166e-01],
#         [6.47580286e-01, 9.10823490e-01, 2.14327867e-01],
#         [7.92449817e-01, 5.97383655e-01, 3.21731880e-01],
#         ...,
#         [9.14232274e-01, 7.66632252e-01, 8.85448454e-01],
#         [8.01919054e-01, 1.82738795e-01, 2.25656834e-01],
#         [7.83231194e-01, 9.19331433e-01, 1.83937299e-01]],
#
#        [[1.02884045e-01, 8.28895162e-01, 6.23523363e-01],
#         [3.10642261e-02, 2.56044389e-01, 3.06693985e-01],
#         [8.09647849e-01, 1.49496763e-01, 8.89616598e-01],
#         ...,
#         [1.71286370e-01, 4.80745263e-01, 9.46479485e-01],
#         [8.77397295e-01, 4.62117427e-01, 9.45165805e-01],
#         [1.22715911e-01, 4.49568304e-01, 7.03836488e-01]]])

# %% [markdown]
# ## 12. Save array4 at your system and load it back

# %%
np.save("array4.npy", array4)

# %%
np.load("array4.npy")
# Out:
# array([[[5.00000000e+01, 7.20000000e+01, 9.50000000e+01],
#         [5.70000000e+01, 7.90000000e+01, 1.02000000e+02],
#         [3.70000000e+01, 5.90000000e+01, 8.20000000e+01],
#         ...,
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00],
#         [3.00000000e+00, 2.00000000e+00, 0.00000000e+00]],
#
#        [[4.30000000e+01, 6.80000000e+01, 9.00000000e+01],
#         [4.60000000e+01, 7.10000000e+01, 9.30000000e+01],
#         [3.90000000e+01, 6.40000000e+01, 8.60000000e+01],
#         ...,
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         [1.00000000e+00, 1.00000000e+00, 1.00000000e+00]],
#
#        [[4.10000000e+01, 6.60000000e+01, 8.80000000e+01],
#         [3.30000000e+01, 5.80000000e+01, 8.00000000e+01],
#         [4.00000000e+01, 6.50000000e+01, 8.70000000e+01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[3.29891444e-01, 9.43673815e-01, 3.50068070e-01],
#         [1.92637855e-01, 2.95057392e-01, 9.25443149e-01],
#         [7.61222656e-01, 2.39532629e-01, 8.73680575e-01],
#         ...,
#         [7.27397907e-01, 3.73350888e-01, 5.80109743e-01],
#         [6.41273533e-01, 4.64048017e-01, 1.52815829e-01],
#         [9.40563043e-01, 6.73622595e-01, 5.14337089e-01]],
#
#        [[5.98202782e-01, 7.32695938e-01, 4.23676166e-01],
#         [6.47580286e-01, 9.10823490e-01, 2.14327867e-01],
#         [7.92449817e-01, 5.97383655e-01, 3.21731880e-01],
#         ...,
#         [9.14232274e-01, 7.66632252e-01, 8.85448454e-01],
#         [8.01919054e-01, 1.82738795e-01, 2.25656834e-01],
#         [7.83231194e-01, 9.19331433e-01, 1.83937299e-01]],
#
#        [[1.02884045e-01, 8.28895162e-01, 6.23523363e-01],
#         [3.10642261e-02, 2.56044389e-01, 3.06693985e-01],
#         [8.09647849e-01, 1.49496763e-01, 8.89616598e-01],
#         ...,
#         [1.71286370e-01, 4.80745263e-01, 9.46479485e-01],
#         [8.77397295e-01, 4.62117427e-01, 9.45165805e-01],
#         [1.22715911e-01, 4.49568304e-01, 7.03836488e-01]]])
